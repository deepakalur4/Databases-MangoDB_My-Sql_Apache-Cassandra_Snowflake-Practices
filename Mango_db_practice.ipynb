# %%
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://deepak:9945971432@mymangodbclsuter.4kgsdhr.mongodb.net/?retryWrites=true&w=majority&appName=mymangodbclsuter"
# Create a new client and connect to the server
client = MongoClient(uri)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
client.list_database_names()
# Out:
# ['my_first_mango_db', 'sample_mflix', 'admin', 'local']

# %%
database=client["my_first_mango_db"]

# %%
database.list_collection_names()
# Out:
# ['orders']

# %%
collection=database["orders"]

# %%
data={"name":"Deepak","Place":"Lakshmeshwar","age":50}

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('665b296dd0ea4adb7f122f42'), acknowledged=True)

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.to_dict("records")
# Out:
# [{'sepal_length': 5.1,
#   'sepal_width': 3.5,
#   'petal_length': 1.4,
#   'petal_width': 0.2,
#   'species': 'setosa'},
#  {'sepal_length': 4.9,
#   'sepal_width': 3.0,
#   'petal_length': 1.4,
#   'petal_width': 0.2,
#   'species': 'setosa'},
#  {'sepal_length': 4.7,
#   'sepal_width': 3.2,
#   'petal_length': 1.3,
#   'petal_width': 0.2,
#   'species': 'setosa'},
#  {'sepal_length': 4.6,
#   'sepal_width': 3.1,
#   'petal_length': 1.5,
#   'petal_width': 0.2,
#   'species': 'setosa'},
#  {'sepal_length': 5.0,
#   'sepal_width': 3.6,
#   'petal_length': 1.4,
#   'petal_width': 0.2,
#   'species': 'setosa'},
#  {'sepal_length': 5.4,
#   'sepal_width': 3.9,
#   'petal_length': 1.7,
#   'petal_width': 0.4,
#   'species': 'setosa'},
#  {'sepal_length': 4.6,
#   'sepal_width': 3.4,
#   'petal_length': 1.4,
#   'petal_width': 0.3,
#   'species': 'setosa'},
#  {'sepal_length': 5.0,
#   'sepal_width': 3.4,
#   'petal_length': 1.5,
#   'petal_width': 0.2,
#   'species': 'setosa'},
# ...

# %%
rec=df.to_dict("records")

# %%
collection.insert_many(rec)
# Out:
# InsertManyResult([ObjectId('665b296fd0ea4adb7f122f43'), ObjectId('665b296fd0ea4adb7f122f44'), ObjectId('665b296fd0ea4adb7f122f45'), ObjectId('665b296fd0ea4adb7f122f46'), ObjectId('665b296fd0ea4adb7f122f47'), ObjectId('665b296fd0ea4adb7f122f48'), ObjectId('665b296fd0ea4adb7f122f49'), ObjectId('665b296fd0ea4adb7f122f4a'), ObjectId('665b296fd0ea4adb7f122f4b'), ObjectId('665b296fd0ea4adb7f122f4c'), ObjectId('665b296fd0ea4adb7f122f4d'), ObjectId('665b296fd0ea4adb7f122f4e'), ObjectId('665b296fd0ea4adb7f122f4f'), ObjectId('665b296fd0ea4adb7f122f50'), ObjectId('665b296fd0ea4adb7f122f51'), ObjectId('665b296fd0ea4adb7f122f52'), ObjectId('665b296fd0ea4adb7f122f53'), ObjectId('665b296fd0ea4adb7f122f54'), ObjectId('665b296fd0ea4adb7f122f55'), ObjectId('665b296fd0ea4adb7f122f56'), ObjectId('665b296fd0ea4adb7f122f57'), ObjectId('665b296fd0ea4adb7f122f58'), ObjectId('665b296fd0ea4adb7f122f59'), ObjectId('665b296fd0ea4adb7f122f5a'), ObjectId('665b296fd0ea4adb7f122f5b'), ObjectId('665b296fd0ea4adb7f12
# ...

# %%
client.list_database_names()
# Out:
# ['my_first_mango_db', 'sample_mflix', 'admin', 'local']

# %%
database.list_collection_names()
# Out:
# ['orders']

# %%
from pprint import pprint

# %%
documents = collection.find()

# %%
for i in documents:
    pprint(i)
# Out:
# {'Place': 'Lakshmeshwar',
#  '_id': ObjectId('665b2540d0ea4adb7f122e12'),
#  'age': 50,
#  'name': 'Deepak'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e1c'),
#  'petal_length': 1.5,
#  'petal_width': 0.1,
#  'sepal_length': 4.9,
#  'sepal_width': 3.1,
#  'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e25'),
#  'petal_length': 1.7,
#  'petal_width': 0.3,
#  'sepal_length': 5.7,
#  'sepal_width': 3.8,
#  'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e16'),
#  'petal_length': 1.5,
#  'petal_width': 0.2,
#  'sepal_length': 4.6,
#  'sepal_width': 3.1,
#  'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e2e'),
#  'petal_length': 1.5,
#  'petal_width': 0.2,
#  'sepal_length': 5.2,
#  'sepal_width': 3.5,
#  'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e2a'),
#  'petal_length': 1.7,
#  'petal_width': 0.5,
#  'sepal_length': 5.1,
#  'sepal_width': 3.3,
#  'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e30'),
# ...

# %%
for i in collection.find({},{"sepal_width"}):
    pprint(i)
# Out:
# {'_id': ObjectId('665b2540d0ea4adb7f122e12')}
# {'_id': ObjectId('665b2590d0ea4adb7f122e1c'), 'sepal_width': 3.1}
# {'_id': ObjectId('665b2590d0ea4adb7f122e25'), 'sepal_width': 3.8}
# {'_id': ObjectId('665b2590d0ea4adb7f122e16'), 'sepal_width': 3.1}
# {'_id': ObjectId('665b2590d0ea4adb7f122e2e'), 'sepal_width': 3.5}
# {'_id': ObjectId('665b2590d0ea4adb7f122e2a'), 'sepal_width': 3.3}
# {'_id': ObjectId('665b2590d0ea4adb7f122e30'), 'sepal_width': 3.2}
# {'_id': ObjectId('665b2590d0ea4adb7f122e47'), 'sepal_width': 3.1}
# {'_id': ObjectId('665b2590d0ea4adb7f122e48'), 'sepal_width': 2.3}
# {'_id': ObjectId('665b2590d0ea4adb7f122e21'), 'sepal_width': 4.0}
# {'_id': ObjectId('665b2590d0ea4adb7f122e29'), 'sepal_width': 3.6}
# {'_id': ObjectId('665b2590d0ea4adb7f122e3e'), 'sepal_width': 3.5}
# {'_id': ObjectId('665b2590d0ea4adb7f122e46'), 'sepal_width': 3.2}
# {'_id': ObjectId('665b2590d0ea4adb7f122e50'), 'sepal_width': 3.0}
# {'_id': ObjectId('665b2590d0ea4adb7f122e52'), 'sepal_width': 2.9}
# ...

# %%
for i in collection.find({"sepal_length":5.0}):
    print(i)
# Out:
# {'_id': ObjectId('665b2590d0ea4adb7f122e3e'), 'sepal_length': 5.0, 'sepal_width': 3.5, 'petal_length': 1.6, 'petal_width': 0.6, 'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e17'), 'sepal_length': 5.0, 'sepal_width': 3.6, 'petal_length': 1.4, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e2d'), 'sepal_length': 5.0, 'sepal_width': 3.4, 'petal_length': 1.6, 'petal_width': 0.4, 'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e44'), 'sepal_length': 5.0, 'sepal_width': 3.3, 'petal_length': 1.4, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e3b'), 'sepal_length': 5.0, 'sepal_width': 3.5, 'petal_length': 1.3, 'petal_width': 0.3, 'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e36'), 'sepal_length': 5.0, 'sepal_width': 3.2, 'petal_length': 1.2, 'petal_width': 0.2, 'species': 'setosa'}
# ...

# %%
for i in collection.find({"sepal_length":{"$gt":5.0}}):
    print(i)
# Out:
# {'_id': ObjectId('665b2590d0ea4adb7f122e25'), 'sepal_length': 5.7, 'sepal_width': 3.8, 'petal_length': 1.7, 'petal_width': 0.3, 'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e2e'), 'sepal_length': 5.2, 'sepal_width': 3.5, 'petal_length': 1.5, 'petal_width': 0.2, 'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e2a'), 'sepal_length': 5.1, 'sepal_width': 3.3, 'petal_length': 1.7, 'petal_width': 0.5, 'species': 'setosa'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e47'), 'sepal_length': 6.9, 'sepal_width': 3.1, 'petal_length': 4.9, 'petal_width': 1.5, 'species': 'versicolor'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e48'), 'sepal_length': 5.5, 'sepal_width': 2.3, 'petal_length': 4.0, 'petal_width': 1.3, 'species': 'versicolor'}
# {'_id': ObjectId('665b2590d0ea4adb7f122e21'), 'sepal_length': 5.8, 'sepal_width': 4.0, 'petal_length': 1.2, 'petal_width': 0.2, 'species': 'setosa'}
# ...

# %%
collection.orders.drop()

# %%
documents = list(collection.find())

# %%
df = pd.DataFrame(documents)

# %%
df.head()
# Out:
#                         _id    name         Place   age  sepal_length  \
# 0  665b2540d0ea4adb7f122e12  Deepak  Lakshmeshwar  50.0           NaN
# 1  665b2590d0ea4adb7f122e1c     NaN           NaN   NaN           4.9
# 2  665b2590d0ea4adb7f122e25     NaN           NaN   NaN           5.7
# 3  665b2590d0ea4adb7f122e16     NaN           NaN   NaN           4.6
# 4  665b2590d0ea4adb7f122e2e     NaN           NaN   NaN           5.2
#
#    sepal_width  petal_length  petal_width species
# 0          NaN           NaN          NaN     NaN
# 1          3.1           1.5          0.1  setosa
# 2          3.8           1.7          0.3  setosa
# 3          3.1           1.5          0.2  setosa
# 4          3.5           1.5          0.2  setosa
